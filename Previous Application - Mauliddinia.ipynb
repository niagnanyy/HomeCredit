# %% [markdown]
# # Finpro Stage 1 - EDA - Previous Application

# %% [markdown]
# # Group 3 <br>
# **Byte Me** <br>
# Hijir Della Wirasti <br>
# Mauliddinia Iftikhar Agnany <br>
# Jericho Medion Haryono <br>
# Fakhri Dwi Nugroho <br>
# Ryan Nofandi <br>
# Johannes Sibarani <br>
# Achmad Fichri Rachmadhani <br>
# Muhammad Naufal <br>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


print('numpy version : ',np.__version__)
print('pandas version : ',pd.__version__)
print('seaborn version : ',sns.__version__)
# Out:
# numpy version :  1.26.4
# pandas version :  2.2.2
# seaborn version :  0.13.2

# %%
sns.set(rc={'figure.figsize':(20.7,8.27)})
sns.set_style("whitegrid")
sns.color_palette("dark")
plt.style.use("fivethirtyeight")

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = 12, 4
rcParams['lines.linewidth'] = 3
rcParams['xtick.labelsize'] = 'x-large'
rcParams['ytick.labelsize'] = 'x-large'

# %% [markdown]
# # Load and Describe Data

# %% [markdown]
# ## Load Data

# %%
import numpy as np
import pandas as pd
# Load the data from the CSV file
data = pd.read_csv('//Users/mauliddiniaiftikharagnany/Desktop/Data Science/Notebook/previous_application.csv')

# Display the first few rows of the dataset
print("First few rows of the dataset:")
display(data.head())
# Out:
# First few rows of the dataset:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
# ...

# %% [markdown]
# ## Describe Data

# %%
# Display info about the dataset
print("\nInfo about the dataset:")
data.info()
# Out:
# Info about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
# ...

# %%
# Display descriptive statistics
print("\nDescriptive statistics of the dataset:")
display(data.describe())
# Out:
# Descriptive statistics of the dataset:
#          SK_ID_PREV    SK_ID_CURR   AMT_ANNUITY  AMT_APPLICATION  \
# count  1.670214e+06  1.670214e+06  1.297979e+06     1.670214e+06
# mean   1.923089e+06  2.783572e+05  1.595512e+04     1.752339e+05
# std    5.325980e+05  1.028148e+05  1.478214e+04     2.927798e+05
# min    1.000001e+06  1.000010e+05  0.000000e+00     0.000000e+00
# 25%    1.461857e+06  1.893290e+05  6.321780e+03     1.872000e+04
# 50%    1.923110e+06  2.787145e+05  1.125000e+04     7.104600e+04
# 75%    2.384280e+06  3.675140e+05  2.065842e+04     1.803600e+05
# max    2.845382e+06  4.562550e+05  4.180581e+05     6.905160e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  1.670213e+06      7.743700e+05     1.284699e+06
# mean   1.961140e+05      6.697402e+03     2.278473e+05
# std    3.185746e+05      2.092150e+04     3.153966e+05
# min    0.000000e+00     -9.000000e-01     0.000000e+00
# 25%    2.416050e+04      0.000000e+00     5.084100e+04
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Pendekatan Numerik (10 Poin)

# %% [markdown]
# ### A. Apakah ada kolom dengan tipe data kurang sesuai, atau nama kolom dan isinya kurang sesuai?

# %% [markdown]
# Kolom dengan tipe data kurang sesuai:
#
# NFLAG_LAST_APPL_IN_DAY dan NFLAG_INSURED_ON_APPROVAL: Kolom ini berisi nilai biner (0 dan 1), yang sebenarnya lebih cocok untuk dikategorikan sebagai kolom kategorikal meskipun mereka berupa angka.
#
# Kolom dengan nama dan isi kurang sesuai:
#
# Tidak ada kolom yang terlihat jelas memiliki nama yang tidak sesuai dengan isinya. Namun, kolom RATE_INTEREST_PRIMARY dan RATE_INTEREST_PRIVILEGED hanya memiliki 5951 data non-null dari total 1,670,214. Kemungkinan ini adalah data yang jarang terisi, dan mungkin perlu diverifikasi lebih lanjut apakah kolom ini relevan atau seharusnya dikelompokkan secara berbeda.

# %%
# Pengelompokan kolom berdasarkan jenisnya

# Kolom numerik (nums)
numerik = [
    'SK_ID_PREV', 
    'SK_ID_CURR', 
    'AMT_ANNUITY', 
    'AMT_APPLICATION', 
    'AMT_CREDIT', 
    'AMT_DOWN_PAYMENT', 
    'AMT_GOODS_PRICE', 
    'HOUR_APPR_PROCESS_START', 
    'RATE_DOWN_PAYMENT', 
    'RATE_INTEREST_PRIMARY', 
    'RATE_INTEREST_PRIVILEGED', 
    'DAYS_DECISION', 
    'CNT_PAYMENT', 
    'DAYS_FIRST_DRAWING', 
    'DAYS_FIRST_DUE', 
    'DAYS_LAST_DUE_1ST_VERSION', 
    'DAYS_LAST_DUE', 
    'DAYS_TERMINATION', 'SELLERPLACE_AREA'
]

# Kolom kategorikal (cats)
categorical = [
    'NAME_CONTRACT_TYPE', 
    'WEEKDAY_APPR_PROCESS_START', 
    'FLAG_LAST_APPL_PER_CONTRACT', 
    'NAME_CASH_LOAN_PURPOSE', 
    'NAME_CONTRACT_STATUS', 
    'NAME_PAYMENT_TYPE', 
    'CODE_REJECT_REASON', 
    'NAME_TYPE_SUITE', 
    'NAME_CLIENT_TYPE', 
    'NAME_GOODS_CATEGORY', 
    'NAME_PORTFOLIO', 
    'NAME_PRODUCT_TYPE', 
    'CHANNEL_TYPE', 
    'NAME_SELLER_INDUSTRY', 
    'NAME_YIELD_GROUP', 
    'PRODUCT_COMBINATION',
    'NFLAG_LAST_APPL_IN_DAY',         # Dipindahkan ke kategorikal
    'NFLAG_INSURED_ON_APPROVAL'       # Dipindahkan ke kategorikal
]

# numerik = numericals
# categorical = categoricals

# %%
data[numerik].describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR   AMT_ANNUITY  AMT_APPLICATION  \
# count  1.670214e+06  1.670214e+06  1.297979e+06     1.670214e+06
# mean   1.923089e+06  2.783572e+05  1.595512e+04     1.752339e+05
# std    5.325980e+05  1.028148e+05  1.478214e+04     2.927798e+05
# min    1.000001e+06  1.000010e+05  0.000000e+00     0.000000e+00
# 25%    1.461857e+06  1.893290e+05  6.321780e+03     1.872000e+04
# 50%    1.923110e+06  2.787145e+05  1.125000e+04     7.104600e+04
# 75%    2.384280e+06  3.675140e+05  2.065842e+04     1.803600e+05
# max    2.845382e+06  4.562550e+05  4.180581e+05     6.905160e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  1.670213e+06      7.743700e+05     1.284699e+06
# mean   1.961140e+05      6.697402e+03     2.278473e+05
# std    3.185746e+05      2.092150e+04     3.153966e+05
# min    0.000000e+00     -9.000000e-01     0.000000e+00
# 25%    2.416050e+04      0.000000e+00     5.084100e+04
# ...

# %%
data[numerik].dtypes
# Out:
# SK_ID_PREV                     int64
# SK_ID_CURR                     int64
# AMT_ANNUITY                  float64
# AMT_APPLICATION              float64
# AMT_CREDIT                   float64
# AMT_DOWN_PAYMENT             float64
# AMT_GOODS_PRICE              float64
# HOUR_APPR_PROCESS_START        int64
# RATE_DOWN_PAYMENT            float64
# RATE_INTEREST_PRIMARY        float64
# RATE_INTEREST_PRIVILEGED     float64
# DAYS_DECISION                  int64
# CNT_PAYMENT                  float64
# DAYS_FIRST_DRAWING           float64
# DAYS_FIRST_DUE               float64
# DAYS_LAST_DUE_1ST_VERSION    float64
# DAYS_LAST_DUE                float64
# DAYS_TERMINATION             float64
# SELLERPLACE_AREA               int64
# dtype: object

# %%
print(data[numerik].describe())
# Out:
#          SK_ID_PREV    SK_ID_CURR   AMT_ANNUITY  AMT_APPLICATION  \
# count  1.670214e+06  1.670214e+06  1.297979e+06     1.670214e+06
# mean   1.923089e+06  2.783572e+05  1.595512e+04     1.752339e+05
# std    5.325980e+05  1.028148e+05  1.478214e+04     2.927798e+05
# min    1.000001e+06  1.000010e+05  0.000000e+00     0.000000e+00
# 25%    1.461857e+06  1.893290e+05  6.321780e+03     1.872000e+04
# 50%    1.923110e+06  2.787145e+05  1.125000e+04     7.104600e+04
# 75%    2.384280e+06  3.675140e+05  2.065842e+04     1.803600e+05
# max    2.845382e+06  4.562550e+05  4.180581e+05     6.905160e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  1.670213e+06      7.743700e+05     1.284699e+06
# mean   1.961140e+05      6.697402e+03     2.278473e+05
# std    3.185746e+05      2.092150e+04     3.153966e+05
# min    0.000000e+00     -9.000000e-01     0.000000e+00
# 25%    2.416050e+04      0.000000e+00     5.084100e+04
# ...

# %% [markdown]
# <h2>Analisis dan Interpretasi Statistik Deskriptif Data Numerik</h2>
#
# <h3>1. Identifikasi Umum dari Data</h3>
# <ul>
#   <li><strong>SK_ID_PREV dan SK_ID_CURR:</strong> Ini adalah ID unik untuk setiap pinjaman dan klien. Karena ini adalah identifier, tidak memiliki signifikansi statistik langsung untuk analisis, selain jumlah total baris yang menunjukkan 1,670,214 entri.</li>
# </ul>
#
# <h3>2. Variabel Terkait Jumlah Pinjaman dan Anuitas</h3>
# <ul>
#   <li><strong>AMT_ANNUITY:</strong>
#     <ul>
#       <li><strong>Mean:</strong> 15,955.12</li>
#       <li><strong>Std Dev:</strong> 14,782.14</li>
#       <li><strong>Min:</strong> 0</li>
#       <li><strong>Max:</strong> 418,058.1</li>
#       <li><strong>Interpretasi:</strong> Terdapat distribusi yang luas pada jumlah anuitas yang mencakup dari 0 hingga 418 ribu. Min menunjukkan beberapa pinjaman tidak memiliki anuitas (mungkin pinjaman yang dibayarkan sekaligus), dan rata-rata anuitas adalah sekitar 15,955, yang menunjukkan pinjaman yang cukup terjangkau bagi mayoritas klien.</li>
#     </ul>
#   </li>
#
#   <li><strong>AMT_APPLICATION:</strong>
#     <ul>
#       <li><strong>Mean:</strong> 175,233.9</li>
#       <li><strong>Std Dev:</strong> 292,779.8</li>
#       <li><strong>Min:</strong> 0</li>
#       <li><strong>Max:</strong> 6,905,160</li>
#       <li><strong>Interpretasi:</strong> Jumlah yang diajukan untuk pinjaman memiliki variasi yang besar dengan standar deviasi yang sangat tinggi. Rata-rata aplikasi adalah 175 ribu, namun terdapat aplikasi hingga 6.9 juta. Rentang yang besar menunjukkan adanya berbagai jenis pinjaman, dari pinjaman kecil hingga pinjaman besar.</li>
#     </ul>
#   </li>
#
#   <li><strong>AMT_CREDIT:</strong>
#     <ul>
#       <li><strong>Mean:</strong> 196,114</li>
#       <li><strong>Std Dev:</strong> 318,574.6</li>
#       <li><strong>Min:</strong> 0</li>
#       <li><strong>Max:</strong> 6,905,160</li>
#       <li><strong>Interpretasi:</strong> Jumlah kredit yang diberikan sangat terkait dengan jumlah yang diminta (AMT_APPLICATION), dengan rata-rata sekitar 196 ribu. Standar deviasi yang tinggi menunjukkan distribusi pinjaman dari jumlah kecil hingga jumlah sangat besar.</li>
#     </ul>
#   </li>
#
#   <li><strong>AMT_DOWN_PAYMENT:</strong>
#     <ul>
#       <li><strong>Mean:</strong> 6,697.4</li>
#       <li><strong>Std Dev:</strong> 20,921.5</li>
#       <li><strong>Min:</strong> -0.9</li>
#       <li><strong>Max:</strong> 3,060,045</li>
#       <li><strong>Interpretasi:</strong> Rata-rata uang muka adalah 6,697, tetapi terdapat variasi yang sangat besar hingga 3 juta, menandakan ada pinjaman besar yang membutuhkan uang muka yang sangat tinggi. Nilai minimum negatif mungkin menunjukkan beberapa anomali data atau kasus khusus.</li>
#     </ul>
#   </li>
#
#   <li><strong>AMT_GOODS_PRICE:</strong>
#     <ul>
#       <li><strong>Mean:</strong> 227,847.3</li>
#       <li><strong>Std Dev:</strong> 315,396.6</li>
#       <li><strong>Min:</strong> 0</li>
#       <li><strong>Max:</strong> 6,905,160</li>
#       <li><strong>Interpretasi:</strong> Harga barang yang dibiayai dengan pinjaman rata-rata sebesar 227 ribu. Namun, dengan standar deviasi yang sangat tinggi, ada variasi besar dalam harga barang dari yang sangat murah hingga sangat mahal (hingga 6.9 juta).</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>3. Variabel Terkait Waktu</h3>
# <ul>
#   <li><strong>DAYS_DECISION:</strong>
#     <ul>
#       <li><strong>Mean:</strong> -880.68</li>
#       <li><strong>Std Dev:</strong> 779.1</li>
#       <li><strong>Min:</strong> -2,922</li>
#       <li><strong>Max:</strong> -1</li>
#       <li><strong>Interpretasi:</strong> Waktu keputusan rata-rata sekitar 880 hari sebelum titik referensi (mungkin tanggal aplikasi). Nilai negatif menunjukkan bahwa keputusan dilakukan jauh sebelum batas waktu yang diberikan, dengan beberapa keputusan bahkan 2,922 hari sebelumnya.</li>
#     </ul>
#   </li>
#
#   <li><strong>HOUR_APPR_PROCESS_START:</strong>
#     <ul>
#       <li><strong>Mean:</strong> 12.48</li>
#       <li><strong>Std Dev:</strong> 3.33</li>
#       <li><strong>Min:</strong> 0</li>
#       <li><strong>Max:</strong> 23</li>
#       <li><strong>Interpretasi:</strong> Aplikasi proses dimulai rata-rata di sekitar pukul 12 siang, dengan distribusi yang cukup merata sepanjang hari, dari pukul 0 (tengah malam) hingga pukul 23 (11 malam).</li>
#     </ul>
#   </li>
#
#   <li><strong>DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_LAST_DUE, DAYS_TERMINATION:</strong>
#     <ul>
#       <li>Rentang tanggal ini menggambarkan berbagai aspek dari siklus pinjaman mulai dari pengambilan pertama hingga jatuh tempo terakhir. Banyak dari variabel ini menunjukkan nilai-nilai negatif, yang berarti tanggal tersebut dihitung mundur dari waktu referensi tertentu.</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>4. Variabel Terkait Pembayaran dan Suku Bunga</h3>
# <ul>
#   <li><strong>CNT_PAYMENT:</strong>
#     <ul>
#       <li><strong>Mean:</strong> 16.05</li>
#       <li><strong>Std Dev:</strong> 14.57</li>
#       <li><strong>Min:</strong> 0</li>
#       <li><strong>Max:</strong> 84</li>
#       <li><strong>Interpretasi:</strong> Jumlah pembayaran cicilan rata-rata adalah 16, tetapi bisa mencapai hingga 84 kali cicilan. Variasi ini menggambarkan perbedaan dalam struktur pinjaman (misalnya, pinjaman jangka pendek dengan cicilan sedikit vs pinjaman jangka panjang dengan cicilan banyak).</li>
#     </ul>
#   </li>
#
#   <li><strong>RATE_DOWN_PAYMENT:</strong>
#     <ul>
#       <li><strong>Mean:</strong> 0.0796</li>
#       <li><strong>Std Dev:</strong> 0.1078</li>
#       <li><strong>Min:</strong> -0.000015</li>
#       <li><strong>Max:</strong> 1.0</li>
#       <li><strong>Interpretasi:</strong> Rata-rata uang muka adalah 7.96% dari total pinjaman, dengan rentang yang cukup besar (dari hampir nol hingga 100%).</li>
#     </ul>
#   </li>
#
#   <li><strong>RATE_INTEREST_PRIMARY dan RATE_INTEREST_PRIVILEGED:</strong>
#     <ul>
#       <li>Rata-rata suku bunga utama adalah 18.83%, dengan suku bunga istimewa sebesar 77.35%. Namun, data ini terbatas hanya pada sekitar 5,951 observasi, yang mungkin menunjukkan bahwa sebagian besar pinjaman tidak melibatkan suku bunga istimewa.</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>5. Variabel Terkait Lokasi Penjual</h3>
# <ul>
#   <li><strong>SELLERPLACE_AREA:</strong>
#     <ul>
#       <li><strong>Mean:</strong> 313.95</li>
#       <li><strong>Std Dev:</strong> 7,127.44</li>
#       <li><strong>Min:</strong> -1</li>
#       <li><strong>Max:</strong> 4,000,000</li>
#       <li><strong>Interpretasi:</strong> Lokasi penjual memiliki rentang yang sangat lebar, menunjukkan bahwa data lokasi sangat bervariasi. Nilai negatif dan tinggi mungkin menunjukkan kesalahan data atau outlier yang signifikan.</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>Kesimpulan Umum:</h3>
# <ul>
#   <li>Data menunjukkan rentang yang sangat luas dalam berbagai aspek, terutama jumlah kredit, anuitas, harga barang, dan uang muka.</li>
#   <li>Beberapa variabel waktu menunjukkan bagaimana pinjaman bergerak melalui siklus pembayaran, dari pengambilan hingga terminasi.</li>
#   <li>Variabel terkait lokasi penjual dan suku bunga memiliki beberapa nilai anomali yang mungkin memerlukan pembersihan lebih lanjut.</li>
# </ul>

# %%
data[categorical].describe()
# Out:
#        NFLAG_LAST_APPL_IN_DAY  NFLAG_INSURED_ON_APPROVAL
# count            1.670214e+06              997149.000000
# mean             9.964675e-01                   0.332570
# std              5.932963e-02                   0.471134
# min              0.000000e+00                   0.000000
# 25%              1.000000e+00                   0.000000
# 50%              1.000000e+00                   0.000000
# 75%              1.000000e+00                   1.000000
# max              1.000000e+00                   1.000000

# %%
data[categorical].dtypes
# Out:
# NAME_CONTRACT_TYPE              object
# WEEKDAY_APPR_PROCESS_START      object
# FLAG_LAST_APPL_PER_CONTRACT     object
# NAME_CASH_LOAN_PURPOSE          object
# NAME_CONTRACT_STATUS            object
# NAME_PAYMENT_TYPE               object
# CODE_REJECT_REASON              object
# NAME_TYPE_SUITE                 object
# NAME_CLIENT_TYPE                object
# NAME_GOODS_CATEGORY             object
# NAME_PORTFOLIO                  object
# NAME_PRODUCT_TYPE               object
# CHANNEL_TYPE                    object
# NAME_SELLER_INDUSTRY            object
# NAME_YIELD_GROUP                object
# PRODUCT_COMBINATION             object
# NFLAG_LAST_APPL_IN_DAY           int64
# NFLAG_INSURED_ON_APPROVAL      float64
# dtype: object

# %%
# Menampilkan deskripsi untuk semua tipe data, termasuk object dan numerik
data[categorical].describe(include='all')
# Out:
#        NAME_CONTRACT_TYPE WEEKDAY_APPR_PROCESS_START  \
# count             1670214                    1670214
# unique                  4                          7
# top            Cash loans                    TUESDAY
# freq               747553                     255118
# mean                  NaN                        NaN
# std                   NaN                        NaN
# min                   NaN                        NaN
# 25%                   NaN                        NaN
# 50%                   NaN                        NaN
# 75%                   NaN                        NaN
# max                   NaN                        NaN
#
#        FLAG_LAST_APPL_PER_CONTRACT NAME_CASH_LOAN_PURPOSE  \
# count                      1670214                1670214
# unique                           2                     25
# top                              Y                    XAP
# freq                       1661739                 922661
# ...

# %%
data['NFLAG_LAST_APPL_IN_DAY'] = data['NFLAG_LAST_APPL_IN_DAY'].astype('object')
data['NFLAG_INSURED_ON_APPROVAL'] = data['NFLAG_INSURED_ON_APPROVAL'].astype('object')

# %%
data[categorical].dtypes
# Out:
# NAME_CONTRACT_TYPE             object
# WEEKDAY_APPR_PROCESS_START     object
# FLAG_LAST_APPL_PER_CONTRACT    object
# NAME_CASH_LOAN_PURPOSE         object
# NAME_CONTRACT_STATUS           object
# NAME_PAYMENT_TYPE              object
# CODE_REJECT_REASON             object
# NAME_TYPE_SUITE                object
# NAME_CLIENT_TYPE               object
# NAME_GOODS_CATEGORY            object
# NAME_PORTFOLIO                 object
# NAME_PRODUCT_TYPE              object
# CHANNEL_TYPE                   object
# NAME_SELLER_INDUSTRY           object
# NAME_YIELD_GROUP               object
# PRODUCT_COMBINATION            object
# NFLAG_LAST_APPL_IN_DAY         object
# NFLAG_INSURED_ON_APPROVAL      object
# dtype: object

# %%
data[categorical].describe()
# Out:
#        NAME_CONTRACT_TYPE WEEKDAY_APPR_PROCESS_START  \
# count             1670214                    1670214
# unique                  4                          7
# top            Cash loans                    TUESDAY
# freq               747553                     255118
#
#        FLAG_LAST_APPL_PER_CONTRACT NAME_CASH_LOAN_PURPOSE  \
# count                      1670214                1670214
# unique                           2                     25
# top                              Y                    XAP
# freq                       1661739                 922661
#
#        NAME_CONTRACT_STATUS      NAME_PAYMENT_TYPE CODE_REJECT_REASON  \
# count               1670214                1670214            1670214
# unique                    4                      4                  9
# top                Approved  Cash through the bank                XAP
# freq                1036781                1033552            1353093
#
# ...

# %%
print(data[categorical].describe())
# Out:
#        NAME_CONTRACT_TYPE WEEKDAY_APPR_PROCESS_START  \
# count             1670214                    1670214
# unique                  4                          7
# top            Cash loans                    TUESDAY
# freq               747553                     255118
#
#        FLAG_LAST_APPL_PER_CONTRACT NAME_CASH_LOAN_PURPOSE  \
# count                      1670214                1670214
# unique                           2                     25
# top                              Y                    XAP
# freq                       1661739                 922661
#
#        NAME_CONTRACT_STATUS      NAME_PAYMENT_TYPE CODE_REJECT_REASON  \
# count               1670214                1670214            1670214
# unique                    4                      4                  9
# top                Approved  Cash through the bank                XAP
# freq                1036781                1033552            1353093
#
# ...

# %% [markdown]
# <h2>Analisis dan Interpretasi Statistik Deskriptif Data Kategorikal</h2>
#
# <h3>1. Tipe Kontrak dan Proses Aplikasi</h3>
# <ul>
#   <li>
#     <strong>NAME_CONTRACT_TYPE:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 4 (Cash loans, Consumer loans, Revolving loans, XNA)</li>
#       <li><strong>Top:</strong> Cash loans (747,553)</li>
#       <li><strong>Interpretasi:</strong> Mayoritas kontrak dalam dataset adalah pinjaman tunai. Hal ini menunjukkan bahwa kebanyakan aplikasi terkait dengan pengajuan pinjaman tunai, mungkin untuk keperluan pembelian barang atau jasa.</li>
#     </ul>
#   </li>
#   <li>
#     <strong>WEEKDAY_APPR_PROCESS_START:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 7 (Hari dalam seminggu)</li>
#       <li><strong>Top:</strong> TUESDAY (255,118)</li>
#       <li><strong>Interpretasi:</strong> Aplikasi proses paling banyak dimulai pada hari Selasa. Ini bisa berarti hari tersebut adalah hari sibuk untuk memproses aplikasi, mungkin karena kebijakan atau pola perilaku dari klien dan lembaga keuangan.</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>2. Aplikasi Pinjaman dan Alasan Penolakan</h3>
# <ul>
#   <li>
#     <strong>FLAG_LAST_APPL_PER_CONTRACT:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 2 (Y, N)</li>
#       <li><strong>Top:</strong> Y (1,661,739)</li>
#       <li><strong>Interpretasi:</strong> Sebagian besar aplikasi adalah yang terakhir dalam kontrak. Ini menunjukkan bahwa sebagian besar klien tidak mengajukan lebih dari satu aplikasi untuk satu kontrak.</li>
#     </ul>
#   </li>
#   <li>
#     <strong>NAME_CASH_LOAN_PURPOSE:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 25 (berbagai tujuan)</li>
#       <li><strong>Top:</strong> XAP (922,661)</li>
#       <li><strong>Interpretasi:</strong> XAP adalah kode tujuan terbesar, mungkin merujuk pada pinjaman yang terkait dengan tujuan umum atau tanpa tujuan spesifik. Ini menunjukkan bahwa banyak aplikasi tidak memiliki tujuan spesifik yang jelas atau dilabeli.</li>
#     </ul>
#   </li>
#   <li>
#     <strong>CODE_REJECT_REASON:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 9 (berbagai alasan penolakan)</li>
#       <li><strong>Top:</strong> XAP (1,353,093)</li>
#       <li><strong>Interpretasi:</strong> Alasan penolakan yang paling umum adalah XAP, yang mungkin menunjukkan bahwa alasan penolakan tersebut tidak secara spesifik didokumentasikan atau tidak jelas.</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>3. Status Kontrak dan Tipe Pembayaran</h3>
# <ul>
#   <li>
#     <strong>NAME_CONTRACT_STATUS:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 4 (Approved, Canceled, Refused, Unused offer)</li>
#       <li><strong>Top:</strong> Approved (1,036,781)</li>
#       <li><strong>Interpretasi:</strong> Sebagian besar kontrak yang diajukan disetujui. Ini menunjukkan bahwa proses persetujuan lebih umum daripada penolakan atau pembatalan kontrak.</li>
#     </ul>
#   </li>
#   <li>
#     <strong>NAME_PAYMENT_TYPE:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 4 (Cash through the bank, XNA, etc.)</li>
#       <li><strong>Top:</strong> Cash through the bank (1,033,552)</li>
#       <li><strong>Interpretasi:</strong> Sebagian besar pembayaran dilakukan melalui bank, yang menunjukkan bahwa metode ini adalah yang paling umum digunakan dalam pembayaran pinjaman.</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>4. Tipe Klien dan Kategori Barang</h3>
# <ul>
#   <li>
#     <strong>NAME_CLIENT_TYPE:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 4 (Repeater, New, Refreshed, XNA)</li>
#       <li><strong>Top:</strong> Repeater (1,231,261)</li>
#       <li><strong>Interpretasi:</strong> Sebagian besar klien adalah "Repeater" atau klien yang telah mengajukan pinjaman sebelumnya. Ini menunjukkan bahwa ada banyak klien yang kembali untuk mengajukan pinjaman lagi.</li>
#     </ul>
#   </li>
#   <li>
#     <strong>NAME_GOODS_CATEGORY:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 28 (berbagai kategori barang)</li>
#       <li><strong>Top:</strong> XNA (950,809)</li>
#       <li><strong>Interpretasi:</strong> Kategori barang terbesar adalah XNA, yang menunjukkan bahwa sebagian besar aplikasi mungkin tidak memiliki kategori barang yang jelas, atau tidak diklasifikasikan dengan baik.</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>5. Portofolio dan Tipe Produk</h3>
# <ul>
#   <li>
#     <strong>NAME_PORTFOLIO:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 5 (POS, Cash, Cards, Cars, XNA)</li>
#       <li><strong>Top:</strong> POS (691,011)</li>
#       <li><strong>Interpretasi:</strong> Sebagian besar kontrak adalah portofolio POS (Point of Sale), yang menunjukkan banyak pinjaman digunakan untuk pembelian di tempat penjualan (retail, online, dll).</li>
#     </ul>
#   </li>
#   <li>
#     <strong>NAME_PRODUCT_TYPE:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 3 (X-sell, Walk-in, XNA)</li>
#       <li><strong>Top:</strong> XNA (1,063,666)</li>
#       <li><strong>Interpretasi:</strong> Sebagian besar produk diklasifikasikan sebagai XNA, yang mungkin menunjukkan tidak adanya informasi atau klasifikasi yang tidak jelas mengenai jenis produk yang terlibat dalam aplikasi pinjaman.</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>6. Industri Penjual dan Kelompok Hasil</h3>
# <ul>
#   <li>
#     <strong>NAME_SELLER_INDUSTRY:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 11 (berbagai industri)</li>
#       <li><strong>Top:</strong> XNA (855,720)</li>
#       <li><strong>Interpretasi:</strong> Sebagian besar industri penjual diklasifikasikan sebagai XNA, yang menunjukkan data yang mungkin tidak lengkap atau tidak jelas mengenai industri tempat penjual berasal.</li>
#     </ul>
#   </li>
#   <li>
#     <strong>NAME_YIELD_GROUP:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 5 (Low action, Middle, High, Low normal, XNA)</li>
#       <li><strong>Top:</strong> XNA (517,215)</li>
#       <li><strong>Interpretasi:</strong> Sebagian besar aplikasi diklasifikasikan sebagai XNA dalam hal kelompok hasil (yield group). Ini mungkin menunjukkan data yang hilang atau klasifikasi yang tidak dilakukan dengan jelas.</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>7. Atribut Lainnya</h3>
# <ul>
#   <li>
#     <strong>NFLAG_LAST_APPL_IN_DAY:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 2 (1, 0)</li>
#       <li><strong>Top:</strong> 1 (1,664,314)</li>
#       <li><strong>Interpretasi:</strong> Sebagian besar aplikasi diajukan sebagai yang terakhir pada hari itu, yang menunjukkan pola pengajuan pinjaman yang mungkin teratur atau terjadwal.</li>
#     </ul>
#   </li>
#   <li>
#     <strong>NFLAG_INSURED_ON_APPROVAL:</strong>
#     <ul>
#       <li><strong>Unique:</strong> 2 (0, 1)</li>
#       <li><strong>Top:</strong> 0 (665,527)</li>
#       <li><strong>Interpretasi:</strong> Sebagian besar aplikasi tidak diasuransikan saat persetujuan. Ini menunjukkan bahwa asuransi tidak selalu menjadi bagian dari paket persetujuan pinjaman.</li>
#     </ul>
#   </li>
# </ul>
#
# <h3>Kesimpulan Umum:</h3>
# <ul>
#   <li>Mayoritas pinjaman adalah <strong>cash loans</strong>, dan banyak pinjaman yang sudah disetujui oleh lembaga keuangan.</li>
#   <li>Data menunjukkan adanya banyak kategori yang tidak terklasifikasi dengan baik (misalnya, XNA) dalam beberapa variabel, yang mungkin menunjukkan data yang tidak lengkap atau tidak jelas.</li>
#   <li>Beberapa klien adalah <strong>repeater</strong> yang telah mengajukan pinjaman sebelumnya, dan kebanyakan dari mereka menggunakan <strong>POS</strong> untuk transaksi.</li>
#   <li>Banyak aplikasi memiliki atribut yang sama (misalnya, pengajuan terakhir pada hari itu dan tidak diasuransikan saat disetujui).</li>
# </ul>

# %% [markdown]
# Total:
# 19 kolom numerik
# 18 kolom kategorikal

# %% [markdown]
# ### B. Apakah ada kolom yang memiliki nilai kosong? Jika ada, apa saja?

# %%
#Jumlah data yang null
data.isna().sum()
# Out:
# SK_ID_PREV                           0
# SK_ID_CURR                           0
# NAME_CONTRACT_TYPE                   0
# AMT_ANNUITY                     372235
# AMT_APPLICATION                      0
# AMT_CREDIT                           1
# AMT_DOWN_PAYMENT                895844
# AMT_GOODS_PRICE                 385515
# WEEKDAY_APPR_PROCESS_START           0
# HOUR_APPR_PROCESS_START              0
# FLAG_LAST_APPL_PER_CONTRACT          0
# NFLAG_LAST_APPL_IN_DAY               0
# RATE_DOWN_PAYMENT               895844
# RATE_INTEREST_PRIMARY          1664263
# RATE_INTEREST_PRIVILEGED       1664263
# NAME_CASH_LOAN_PURPOSE               0
# NAME_CONTRACT_STATUS                 0
# DAYS_DECISION                        0
# NAME_PAYMENT_TYPE                    0
# CODE_REJECT_REASON                   0
# NAME_TYPE_SUITE                 820405
# NAME_CLIENT_TYPE                     0
# NAME_GOODS_CATEGORY                  0
# NAME_PORTFOLIO                       0
# ...

# %% [markdown]
# Data yang memiliki nilai kosong ada pada:
#
# 1. AMT_ANNUITY: 372,235 nilai kosong
#
# 2. AMT_DOWN_PAYMENT: 895,844
# 3. AMT_GOODS_PRICE: 385,515
# 4. AMT_CREDIT: 1
# 5. RATE_DOWN_PAYMENT: 895,844
# 6. RATE_INTEREST_PRIMARY: 1,664,263
# 7. RATE_INTEREST_PRIVILEGED: 1,664,263
# 8. NAME_TYPE_SUITE: 820,405
# 9. CNT_PAYMENT: 372,230
# 10. PRODUCT_COMBINATION: 346
# 11. DAYS_FIRST_DRAWING: 673,065
# 12. DAYS_FIRST_DUE: 673,065
# 13. DAYS_LAST_DUE_1ST_VERSION: 673,065
# 14. DAYS_LAST_DUE: 673,065
# 15. DAYS_TERMINATION: 673,065
# 16. NFLAG_INSURED_ON_APPROVAL: 673,065

# %%
import pandas as pd

# Total number of rows in the dataset
total_rows = 1670214

# Dictionary with column names and their corresponding missing values
missing_values = {
    'AMT_ANNUITY': 372235,
    'AMT_DOWN_PAYMENT': 895844,
    'AMT_GOODS_PRICE': 385515,
    'AMT_CREDIT': 1,
    'RATE_DOWN_PAYMENT': 895844,
    'RATE_INTEREST_PRIMARY': 1664263,
    'RATE_INTEREST_PRIVILEGED': 1664263,
    'NAME_TYPE_SUITE': 820405,
    'CNT_PAYMENT': 372230,
    'PRODUCT_COMBINATION': 346,
    'DAYS_FIRST_DRAWING': 673065,
    'DAYS_FIRST_DUE': 673065,
    'DAYS_LAST_DUE_1ST_VERSION': 673065,
    'DAYS_LAST_DUE': 673065,
    'DAYS_TERMINATION': 673065,
    'NFLAG_INSURED_ON_APPROVAL': 673065
}

# df dan hitung presentase
missing_df = pd.DataFrame(list(missing_values.items()), columns=['Column', 'Missing Values'])
missing_df['Percentage Missing'] = (missing_df['Missing Values'] / total_rows) * 100

#klasifikasi 
missing_df['Action'] = missing_df['Percentage Missing'].apply(lambda x: 'Keep' if x < 5 else 'Drop')

# Display the DataFrame
print(missing_df)
# Out:
#                        Column  Missing Values  Percentage Missing Action
# 0                 AMT_ANNUITY          372235           22.286665   Drop
# 1            AMT_DOWN_PAYMENT          895844           53.636480   Drop
# 2             AMT_GOODS_PRICE          385515           23.081773   Drop
# 3                  AMT_CREDIT               1            0.000060   Keep
# 4           RATE_DOWN_PAYMENT          895844           53.636480   Drop
# 5       RATE_INTEREST_PRIMARY         1664263           99.643698   Drop
# 6    RATE_INTEREST_PRIVILEGED         1664263           99.643698   Drop
# 7             NAME_TYPE_SUITE          820405           49.119754   Drop
# 8                 CNT_PAYMENT          372230           22.286366   Drop
# 9         PRODUCT_COMBINATION             346            0.020716   Keep
# 10         DAYS_FIRST_DRAWING          673065           40.298129   Drop
# 11             DAYS_FIRST_DUE          673065           40.298129   Drop
# ...

# %% [markdown]
# ### C. Apakah ada kolom yang memiliki nilai summary agak aneh?
# (min/mean/median/max/unique/top/freq)

# %% [markdown]
# <h2>Analisis dan Interpretasi Bagian C</h2>
#
# <h3>Apakah ada kolom yang memiliki nilai summary yang agak aneh? (min/mean/median/max/unique/top/freq)</h3>
#
# <p>Terdapat beberapa kolom yang memiliki nilai summary yang dianggap agak aneh, berikut rinciannya:</p>
#
# <h3>1. <code>AMT_DOWN_PAYMENT</code></h3>
# <ul>
#   <li><strong>Min:</strong> -0.9</li>
#   <li><strong>Max:</strong> 3,060,045</li>
#   <li><strong>Interpretasi:</strong>
#     <p>Nilai minimum negatif (-0.9) pada kolom <code>AMT_DOWN_PAYMENT</code> menunjukkan adanya data yang tidak valid atau anomali. Uang muka seharusnya bernilai positif, sehingga kemungkinan nilai ini adalah hasil kesalahan input atau perlu dilakukan pembersihan data.</p>
#   </li>
# </ul>
#
# <h3>2. <code>RATE_DOWN_PAYMENT</code></h3>
# <ul>
#   <li><strong>Min:</strong> -0.000015</li>
#   <li><strong>Max:</strong> 1.0</li>
#   <li><strong>Interpretasi:</strong>
#     <p>Nilai minimum negatif pada kolom <code>RATE_DOWN_PAYMENT</code> juga menunjukkan adanya data yang tidak valid, karena suku bunga uang muka (rate down payment) seharusnya tidak negatif. Nilai negatif menunjukkan kesalahan input atau anomali yang harus dibersihkan.</p>
#   </li>
# </ul>
#
# <h3>3. <code>SELLERPLACE_AREA</code></h3>
# <ul>
#   <li><strong>Min:</strong> -1</li>
#   <li><strong>Max:</strong> 4,000,000</li>
#   <li><strong>Interpretasi:</strong>
#     <p>Nilai minimum -1 dan nilai maksimum yang sangat tinggi (4 juta) menunjukkan adanya anomali dalam kolom <code>SELLERPLACE_AREA</code>. Nilai -1 mungkin mewakili lokasi yang tidak terdefinisi, sementara nilai maksimum 4 juta kemungkinan adalah outlier yang memerlukan verifikasi lebih lanjut.</p>
#   </li>
# </ul>
#
# <h3>4. <code>RATE_INTEREST_PRIMARY</code> dan <code>RATE_INTEREST_PRIVILEGED</code></h3>
# <ul>
#   <li><strong>Jumlah data non-null:</strong> 5,951 dari 1,670,214</li>
#   <li><strong>Interpretasi:</strong>
#     <p>Hanya 5,951 entri yang memiliki nilai pada kolom ini, yang menunjukkan bahwa sebagian besar pinjaman tidak mencantumkan suku bunga utama (<code>RATE_INTEREST_PRIMARY</code>) maupun suku bunga istimewa (<code>RATE_INTEREST_PRIVILEGED</code>). Data ini sangat jarang terisi, sehingga relevansi kolom ini perlu dipertanyakan dalam analisis lebih lanjut.</p>
#   </li>
# </ul>
#
# <h3>5. <code>NFLAG_INSURED_ON_APPROVAL</code></h3>
# <ul>
#   <li><strong>Min:</strong> 0</li>
#   <li><strong>Max:</strong> 1</li>
#   <li><strong>Interpretasi:</strong>
#     <p>Meskipun kolom ini berisi nilai biner (0 dan 1), hanya sekitar 997,149 entri yang mengisi kolom ini. Kolom ini mengindikasikan apakah pinjaman diasuransikan saat persetujuan, namun banyak data yang kosong, sehingga perlu dipastikan relevansinya.</p>
#   </li>
# </ul>
#
# <h3>6. <code>AMT_ANNUITY</code></h3>
# <ul>
#   <li><strong>Min:</strong> 0</li>
#   <li><strong>Max:</strong> 418,058</li>
#   <li><strong>Interpretasi:</strong>
#     <p>Nilai minimum sebesar 0 menunjukkan bahwa beberapa pinjaman mungkin tidak memiliki anuitas (kemungkinan pinjaman lump sum). Variasi yang besar antara minimum dan maksimum juga menunjukkan berbagai jenis struktur pembayaran pinjaman.</p>
#   </li>
# </ul>
#
# <h3>7. <code>DAYS_DECISION</code></h3>
# <ul>
#   <li><strong>Min:</strong> -2,922</li>
#   <li><strong>Max:</strong> -1</li>
#   <li><strong>Interpretasi:</strong>
#     <p>Kolom ini menggambarkan waktu pengambilan keputusan pinjaman dalam hari sebelum titik referensi tertentu. Nilai maksimum -1 menunjukkan keputusan dilakukan satu hari sebelum tanggal referensi, sementara nilai minimum -2,922 menunjukkan keputusan dilakukan hampir 8 tahun sebelumnya. Rentang waktu yang besar ini menunjukkan variasi besar dalam proses persetujuan pinjaman.</p>
#   </li>
# </ul>
#
# <h2>Kesimpulan</h2>
# <ul>
#   <li>Beberapa kolom, seperti <code>AMT_DOWN_PAYMENT</code>, <code>RATE_DOWN_PAYMENT</code>, dan <code>SELLERPLACE_AREA</code> memiliki anomali seperti nilai negatif atau nilai ekstrim yang perlu ditangani melalui pembersihan data.</li>
#   <li>Kolom suku bunga (<code>RATE_INTEREST_PRIMARY</code> dan <code>RATE_INTEREST_PRIVILEGED</code>) memiliki banyak nilai kosong, sehingga relevansinya dalam model analisis lebih lanjut perlu dipertimbangkan.</li>
#   <li>Beberapa kolom, seperti <code>NFLAG_INSURED_ON_APPROVAL</code> dan <code>AMT_ANNUITY</code>, memiliki rentang nilai yang menunjukkan berbagai variasi dalam struktur pinjaman yang perlu dianalisis lebih mendalam.</li>
# </ul>

# %% [markdown]
# ## Pendekatan Grafis

# %% [markdown]
# ### Univariate Analysis (20 Poin)

# %% [markdown]
# Univariate analysis adalah analisis yang hanya melibatkan satu variabel pada satu waktu. Untuk univariate analysis ini, kita akan melihat distribusi dari setiap kolom dalam dataset, baik untuk kolom numerik maupun kategorikal.

# %%
#histogram numerik
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting histogram for each numeric column with more space between plots
plt.figure(figsize=(30, 20))
for i, col in enumerate(numerik, 1):
    plt.subplot(5, 4, i)
    sns.histplot(data[col].dropna(), bins=50, kde=True)
    plt.title(f'Distribution of {col}')

# Adjusting the space between plots
plt.subplots_adjust(wspace=0.4, hspace=0.6)
plt.tight_layout()
plt.show()

# %%
#boxplot numerik
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting box plot for each numeric column
plt.figure(figsize=(30, 20))
for i, col in enumerate(numerik, 1):
    plt.subplot(5, 4, i)
    sns.boxplot(x=data[col].dropna())
    plt.title(f'Box plot of {col}')
    
# Adjusting the space between plots
plt.subplots_adjust(wspace=0.5, hspace=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Analisis dan Interpretasi Distribusi Kolom Numerik</h2>
#
# <ol>
#   <li>
#     <strong>SK_ID_PREV dan SK_ID_CURR:</strong>
#     <ul>
#       <li>Distribusi dari kedua kolom ini sangat merata dengan rentang yang cukup besar.</li>
#       <li>Kedua kolom ini adalah ID unik yang digunakan untuk mengidentifikasi data, sehingga kita tidak dapat menarik kesimpulan signifikan dari distribusinya karena ini hanya pengidentifikasi.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>AMT_ANNUITY, AMT_APPLICATION, AMT_CREDIT, dan AMT_DOWN_PAYMENT:</strong>
#     <ul>
#       <li>Distribusi dari variabel-variabel ini sangat <em>right-skewed</em> (condong ke kanan).</li>
#       <li>Sebagian besar nilai dari kolom-kolom ini berada pada nilai yang rendah, dengan hanya sedikit pengamatan yang memiliki nilai yang sangat tinggi.</li>
#       <li>Ini menunjukkan mayoritas aplikasi memiliki jumlah kredit, pembayaran anuitas, dan uang muka yang relatif kecil, dengan hanya beberapa aplikasi yang memiliki jumlah besar.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>AMT_GOODS_PRICE:</strong>
#     <ul>
#       <li>Distribusinya juga <em>right-skewed</em>, dengan mayoritas barang yang dibiayai bernilai rendah, namun ada beberapa aplikasi dengan harga barang yang jauh lebih tinggi.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>HOUR_APPR_PROCESS_START:</strong>
#     <ul>
#       <li>Distribusi menunjukkan bahwa waktu aplikasi pemrosesan cenderung pada jam kerja aktif, dengan puncak sekitar pukul 10 hingga 14.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>RATE_DOWN_PAYMENT, RATE_INTEREST_PRIMARY, dan RATE_INTEREST_PRIVILEGED:</strong>
#     <ul>
#       <li>Distribusi <strong>RATE_DOWN_PAYMENT</strong> menunjukkan banyak aplikasi memiliki tingkat uang muka yang rendah, dengan sedikit aplikasi yang memiliki tingkat lebih tinggi.</li>
#       <li><strong>RATE_INTEREST_PRIMARY</strong> dan <strong>RATE_INTEREST_PRIVILEGED</strong> menunjukkan bahwa sebagian besar aplikasi memiliki suku bunga dalam kisaran rendah, dengan beberapa pengamatan memiliki tingkat suku bunga yang lebih tinggi.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>CNT_PAYMENT:</strong>
#     <ul>
#       <li>Distribusi ini menunjukkan bahwa mayoritas aplikasi memiliki jumlah pembayaran yang dijadwalkan pada kisaran rendah hingga sedang, dengan beberapa aplikasi memiliki jumlah pembayaran yang jauh lebih tinggi.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>DAYS_DECISION:</strong>
#     <ul>
#       <li>Distribusi ini menunjukkan berapa hari sebelum keputusan diambil terkait dengan aplikasi.</li>
#       <li>Sebagian besar keputusan diambil lebih dekat dengan waktu aplikasi, namun ada juga keputusan yang diambil jauh sebelum waktu aplikasi (dengan nilai negatif).</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_LAST_DUE, dan DAYS_TERMINATION:</strong>
#     <ul>
#       <li>Kolom-kolom ini menunjukkan informasi terkait tanggal penting dalam siklus pinjaman, seperti tanggal penarikan pertama, jatuh tempo pertama, dan tanggal terminasi pinjaman.</li>
#       <li>Distribusi menunjukkan sebagian besar aplikasi memiliki nilai yang sangat rendah atau bahkan negatif (menunjukkan jarak waktu dari hari keputusan).</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>SELLERPLACE_AREA:</strong>
#     <ul>
#       <li>Distribusi menunjukkan sebagian besar nilai berkisar pada area yang kecil, namun terdapat beberapa outliers dengan nilai area yang jauh lebih besar.</li>
#     </ul>
#   </li>
# </ol>
#
# <h3>Kesimpulan Umum:</h3>
# <ul>
#   <li>Sebagian besar variabel numerik menunjukkan distribusi yang condong ke kanan, di mana mayoritas pengamatan berada pada nilai rendah, dengan sedikit pengamatan yang bernilai tinggi.</li>
#   <li>Variabel terkait waktu (seperti <em>DAYS_*</em>) menunjukkan keputusan yang diambil pada waktu yang berbeda-beda, dengan mayoritas keputusan diambil lebih dekat dengan waktu aplikasi.</li>
#   <li>Mayoritas aplikasi memiliki suku bunga dan uang muka rendah, dengan hanya beberapa aplikasi yang memiliki nilai tinggi.</li>
# </ul>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Menentukan jumlah baris dan kolom
n_cols = 3
n_rows = (len(categorical) + n_cols - 1) // n_cols  # Menghitung jumlah baris yang dibutuhkan

# Plotting bar plot for each categorical column with more space and label rotation
plt.figure(figsize=(30, n_rows * 5))
for i, col in enumerate(categorical, 1):
    plt.subplot(n_rows, n_cols, i)  # Menampilkan 3 kolom per baris
    sns.countplot(y=data[col], order=data[col].value_counts().index)
    plt.title(f'Distribution of {col}')
    plt.yticks(rotation=0, fontsize=8)  # Keeping Y-axis labels horizontal with smaller font size
    plt.xticks(fontsize=8)

# Adjusting the space between plots
plt.subplots_adjust(wspace=0.4, hspace=0.9)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Analisis dan Interpretasi Distribusi Kolom Kategorikal</h2>
#
# <ol>
#   <li>
#     <strong>NAME_CONTRACT_TYPE:</strong>
#     <ul>
#       <li>Distribusi: Sebagian besar kontrak adalah "Cash loans" dan "Consumer loans." Kontrak "Revolving loans" sedikit dan hampir tidak ada kontrak bertipe "XNA."</li>
#       <li>Interpretasi: Produk pinjaman yang paling sering diambil adalah pinjaman tunai (cash loans) dan pinjaman konsumen (consumer loans).</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>WEEKDAY_APPR_PROCESS_START:</strong>
#     <ul>
#       <li>Distribusi: Proses aplikasi tersebar merata sepanjang minggu, dengan sedikit penurunan pada hari Sabtu dan Minggu.</li>
#       <li>Interpretasi: Aktivitas aplikasi cenderung lebih tinggi pada hari kerja dan lebih rendah di akhir pekan, kemungkinan karena jam kerja yang lebih pendek atau libur.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>FLAG_LAST_APPL_PER_CONTRACT:</strong>
#     <ul>
#       <li>Distribusi: Sebagian besar nilai adalah "Y," menunjukkan bahwa aplikasi tersebut adalah yang terakhir dalam kontrak terkait.</li>
#       <li>Interpretasi: Hampir semua aplikasi merupakan aplikasi terakhir dalam kontrak.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NAME_CASH_LOAN_PURPOSE:</strong>
#     <ul>
#       <li>Distribusi: Banyak aplikasi tidak menyebutkan tujuan (XAP), diikuti oleh kategori seperti "Repairs" dan "Other."</li>
#       <li>Interpretasi: Sebagian besar tujuan pinjaman tidak disebutkan secara spesifik, tetapi pinjaman untuk perbaikan dan keperluan lain cukup umum.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NAME_CONTRACT_STATUS:</strong>
#     <ul>
#       <li>Distribusi: Sebagian besar aplikasi berstatus "Approved" (disetujui), diikuti oleh "Canceled" dan "Refused."</li>
#       <li>Interpretasi: Mayoritas aplikasi berhasil disetujui, sementara sebagian lainnya dibatalkan atau ditolak.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NAME_PAYMENT_TYPE:</strong>
#     <ul>
#       <li>Distribusi: "Cash through the bank" adalah metode pembayaran paling umum, diikuti oleh "Non-cash from your account."</li>
#       <li>Interpretasi: Mayoritas pembayaran dilakukan melalui transfer bank, menunjukkan bahwa metode pembayaran elektronik banyak digunakan.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>CODE_REJECT_REASON:</strong>
#     <ul>
#       <li>Distribusi: Alasan penolakan yang paling umum adalah "XAP" (tidak disebutkan), diikuti oleh "HC" dan "LIMIT."</li>
#       <li>Interpretasi: Banyak alasan penolakan tidak dijelaskan, tetapi batasan kredit (LIMIT) dan skor kredit (HC) mungkin berperan.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NAME_TYPE_SUITE:</strong>
#     <ul>
#       <li>Distribusi: Sebagian besar aplikasi diajukan secara individu (Unaccompanied), diikuti oleh kategori "Family" dan "Spouse, partner."</li>
#       <li>Interpretasi: Sebagian besar pemohon mengajukan aplikasi sendirian, meskipun beberapa mengajukan dengan keluarga atau pasangan.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NAME_CLIENT_TYPE:</strong>
#     <ul>
#       <li>Distribusi: Mayoritas pemohon adalah "Repeater," diikuti oleh "New."</li>
#       <li>Interpretasi: Sebagian besar pemohon adalah pelanggan yang mengajukan ulang pinjaman, dengan pelanggan baru berkontribusi cukup besar.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NAME_GOODS_CATEGORY:</strong>
#     <ul>
#       <li>Distribusi: Kategori "XNA" (tidak dijelaskan) mendominasi, diikuti oleh "Mobile," "Consumer electronics," dan "Computers."</li>
#       <li>Interpretasi: Banyak kategori barang tidak dijelaskan, tetapi barang-barang elektronik seperti ponsel dan peralatan elektronik konsumen sering dibiayai.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NAME_PORTFOLIO:</strong>
#     <ul>
#       <li>Distribusi: Portofolio paling banyak adalah "POS," diikuti oleh "Cash" dan "XNA."</li>
#       <li>Interpretasi: Sebagian besar aplikasi terkait dengan pinjaman di tempat penjualan (POS), serta pinjaman tunai.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NAME_PRODUCT_TYPE:</strong>
#     <ul>
#       <li>Distribusi: "XNA" mendominasi kategori ini, diikuti oleh "X-sell" dan "walk-in."</li>
#       <li>Interpretasi: Banyak produk tidak dijelaskan, tetapi penjualan silang (X-sell) juga cukup umum.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>CHANNEL_TYPE:</strong>
#     <ul>
#       <li>Distribusi: Saluran distribusi "Credit and cash offices" dan "Country-wide" adalah yang paling umum, diikuti oleh "Stone" dan "Regional / Local."</li>
#       <li>Interpretasi: Sebagian besar aplikasi dilakukan melalui kantor kredit dan tunai serta jaringan nasional.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NAME_SELLER_INDUSTRY:</strong>
#     <ul>
#       <li>Distribusi: Sebagian besar penjual berada di kategori "XNA," diikuti oleh "Consumer electronics" dan "Connectivity."</li>
#       <li>Interpretasi: Industri elektronik konsumen dan konektivitas mendominasi sektor yang banyak dibiayai.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NAME_YIELD_GROUP:</strong>
#     <ul>
#       <li>Distribusi: "XNA" mendominasi kategori ini, diikuti oleh "middle" dan "high."</li>
#       <li>Interpretasi: Sebagian besar grup penghasilan tidak dijelaskan, tetapi aplikasi dengan penghasilan menengah dan tinggi cukup umum.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>PRODUCT_COMBINATION:</strong>
#     <ul>
#       <li>Distribusi: Produk "Cash" paling umum, diikuti oleh kombinasi produk "POS household with interest" dan "POS mobile with interest."</li>
#       <li>Interpretasi: Sebagian besar aplikasi terkait produk tunai, diikuti oleh kombinasi produk dengan bunga untuk barang-barang rumah tangga dan barang bergerak.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NFLAG_LAST_APPL_IN_DAY:</strong>
#     <ul>
#       <li>Distribusi: Sebagian besar nilai adalah "1," menunjukkan aplikasi terakhir pada hari tersebut yang diproses.</li>
#       <li>Interpretasi: Aplikasi terakhir pada hari tersebut cenderung menjadi aplikasi terakhir yang diproses.</li>
#     </ul>
#   </li>
#
#   <li>
#     <strong>NFLAG_INSURED_ON_APPROVAL:</strong>
#     <ul>
#       <li>Distribusi: Mayoritas aplikasi tidak diasuransikan saat disetujui.</li>
#       <li>Interpretasi: Sebagian besar pemohon tidak diasuransikan ketika aplikasi mereka disetujui.</li>
#     </ul>
#   </li>
# </ol>
#
# <h3>Kesimpulan Umum:</h3>
# <ul>
#   <li>Banyak kategori didominasi oleh nilai "XNA" yang tidak dijelaskan, menunjukkan ada banyak data yang tidak terdefinisi.</li>
#   <li>Pinjaman tunai dan konsumsi mendominasi, dengan sebagian besar pemohon adalah pelanggan yang mengajukan ulang pinjaman.</li>
#   <li>Proses aplikasi dilakukan melalui saluran distribusi kredit dan tunai serta di tempat penjualan (POS).</li>
#   <li>Industri elektronik konsumen dan konektivitas banyak dibiayai, dengan mayoritas produk adalah tunai atau kombinasi POS dengan bunga.</li>
# </ul>

# %% [markdown]
# ### Multivariate Analysis (10 Poin)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Membuat correlation matrix untuk data numerik
correlation_matrix = data[numerik].corr()

# Plotting heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# <h2>Analisis dan Interpretasi Correlation Heatmap</h2>
#
# <h3>1. Korelasi Sangat Tinggi (di atas 0.9)</h3>
# <ul>
#   <li>
#     <strong>AMT_CREDIT dan AMT_GOODS_PRICE (0.99):</strong>
#     <br>Korelasi sangat tinggi antara jumlah kredit yang diberikan dan harga barang yang dibiayai. Ini sangat logis karena barang yang lebih mahal biasanya memerlukan jumlah kredit yang lebih tinggi.
#   </li>
#   <li>
#     <strong>DAYS_TERMINATION dan DAYS_LAST_DUE_1ST_VERSION (0.93):</strong>
#     <br>Menunjukkan bahwa tanggal terminasi pinjaman sangat terkait dengan tanggal jatuh tempo versi pertama. Ini mengindikasikan bahwa penutupan pinjaman sangat terikat dengan jadwal pembayaran awal.
#   </li>
# </ul>
#
# <h3>2. Korelasi Tinggi (0.75 hingga 0.9)</h3>
# <ul>
#   <li>
#     <strong>AMT_CREDIT dan AMT_APPLICATION (0.99):</strong>
#     <br>Jumlah kredit yang disetujui sangat mendekati jumlah yang diajukan dalam aplikasi, mengindikasikan bahwa sebagian besar aplikasi mendapatkan kredit sesuai dengan permintaan.
#   </li>
#   <li>
#     <strong>DAYS_TERMINATION dan DAYS_LAST_DUE (0.91):</strong>
#     <br>Korelasi ini menunjukkan bahwa waktu jatuh tempo pinjaman sangat memengaruhi tanggal penutupan pinjaman.
#   </li>
#   <li>
#     <strong>DAYS_LAST_DUE dan DAYS_LAST_DUE_1ST_VERSION (0.88):</strong>
#     <br>Konsistensi antara versi pertama jadwal jatuh tempo dan jatuh tempo aktual menunjukkan manajemen pembayaran yang baik.
#   </li>
# </ul>
#
# <h3>3. Korelasi Sedang (0.5 hingga 0.75)</h3>
# <ul>
#   <li>
#     <strong>CNT_PAYMENT dan AMT_ANNUITY (0.68):</strong>
#     <br>Semakin besar jumlah anuitas, semakin banyak cicilan yang dibayarkan. Pinjaman dengan anuitas besar cenderung memiliki lebih banyak pembayaran yang dijadwalkan.
#   </li>
#   <li>
#     <strong>AMT_ANNUITY dan AMT_CREDIT (0.68):</strong>
#     <br>Hubungan ini menunjukkan bahwa semakin besar jumlah kredit, semakin besar kemungkinan anuitas yang harus dibayar oleh peminjam.
#   </li>
#   <li>
#     <strong>DAYS_FIRST_DRAWING dan DAYS_FIRST_DUE (0.51):</strong>
#     <br>Korelasi ini menunjukkan bahwa waktu penarikan pertama memiliki hubungan sedang dengan jatuh tempo pertama, tetapi tidak selalu saling mengikuti secara langsung.
#   </li>
# </ul>
#
# <h3>4. Korelasi Rendah hingga Tidak Signifikan (di bawah 0.5)</h3>
# <ul>
#   <li>
#     <strong>RATE_DOWN_PAYMENT dan sebagian besar variabel lainnya:</strong>
#     <br>Korelasi rendah menunjukkan bahwa rasio uang muka tidak memiliki hubungan kuat dengan variabel numerik lainnya, seperti jumlah kredit atau anuitas. Ini mungkin mengindikasikan bahwa kebijakan uang muka bervariasi secara independen dari jumlah pinjaman atau harga barang.
#   </li>
#   <li>
#     <strong>HOUR_APPR_PROCESS_START dengan variabel lain:</strong>
#     <br>Tidak ada hubungan signifikan antara jam proses aplikasi dan variabel numerik lainnya. Ini logis karena waktu aplikasi tidak diharapkan berpengaruh pada jumlah pinjaman atau pembayaran.
#   </li>
# </ul>
#
# <h3>5. Korelasi Negatif</h3>
# <ul>
#   <li>
#     <strong>DAYS_DECISION dan DAYS_FIRST_DRAWING (-0.38):</strong>
#     <br>Hubungan negatif ini menunjukkan bahwa semakin jauh keputusan dibuat dari tanggal aplikasi, semakin cepat penarikan pertama dilakukan. Korelasi ini moderat dan mungkin menunjukkan adanya percepatan dalam proses pinjaman yang lambat.
#   </li>
#   <li>
#     <strong>DAYS_FIRST_DRAWING dan DAYS_LAST_DUE_1ST_VERSION (-0.80):</strong>
#     <br>Korelasi negatif yang kuat ini menunjukkan bahwa semakin lama waktu antara penarikan pertama dan jatuh tempo versi pertama, semakin panjang masa pinjaman. Ini masuk akal dalam konteks siklus kredit.
#   </li>
# </ul>
#
# <h3>Kesimpulan:</h3>
# <ul>
#   <li><strong>Korelasi Tinggi:</strong> Variabel-variabel seperti AMT_CREDIT, AMT_APPLICATION, dan AMT_GOODS_PRICE memiliki korelasi sangat tinggi, menunjukkan hubungan yang erat antara jumlah pinjaman, harga barang, dan permintaan kredit.</li>
#   <li><strong>Hubungan Kuat di Antara Variabel Waktu:</strong> Variabel seperti DAYS_TERMINATION, DAYS_LAST_DUE, dan DAYS_LAST_DUE_1ST_VERSION sangat terkait, menunjukkan siklus pembayaran yang konsisten.</li>
#   <li><strong>Korelasi Rendah:</strong> Variabel seperti RATE_DOWN_PAYMENT dan HOUR_APPR_PROCESS_START tidak menunjukkan korelasi signifikan dengan variabel lain.</li>
#   <li><strong>Korelasi Negatif:</strong> Terdapat beberapa hubungan negatif yang signifikan, terutama antara variabel waktu, menunjukkan bahwa ada keterlambatan dalam proses penarikan atau pembayaran pinjaman yang berpengaruh pada jadwal lainnya.</li>
# </ul>

# %% [markdown]
# <h2>Insight dan Business Recommendation</h2>
#
# <h3>Insight Utama</h3>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Pastikan variabel data adalah DataFrame yang sudah ada

# 1. Scatter Plot: Jumlah Pinjaman (AMT_CREDIT) vs Anuitas (AMT_ANNUITY)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AMT_CREDIT', y='AMT_ANNUITY', data=data, alpha=0.3)
plt.title('Scatter Plot: Jumlah Pinjaman vs Anuitas', fontsize=14)
plt.xlabel('Jumlah Pinjaman (AMT_CREDIT)')
plt.ylabel('Anuitas (AMT_ANNUITY)')
plt.show()

# %% [markdown]
# <h4>1. Jumlah Pinjaman dan Anuitas</h4>
# <p>Mayoritas pinjaman yang diberikan berada di kisaran jumlah kecil hingga menengah, dengan anuitas yang relatif rendah. Sebagian besar aplikasi mendapatkan jumlah kredit yang sangat mendekati jumlah yang diajukan, dan jumlah anuitas yang dibayarkan berkorelasi dengan jumlah kredit yang diberikan. Namun, terdapat beberapa aplikasi yang memiliki jumlah pinjaman dan anuitas yang sangat besar, meskipun ini jarang terjadi.</p>

# %%
# 2. Histogram: Distribusi Rasio Uang Muka (RATE_DOWN_PAYMENT)
plt.figure(figsize=(10, 6))
sns.histplot(data['RATE_DOWN_PAYMENT'].dropna(), bins=50, kde=True)
plt.title('Distribusi Rasio Uang Muka', fontsize=14)
plt.xlabel('Rasio Uang Muka (RATE_DOWN_PAYMENT)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# <h4>2. Uang Muka dan Rasio Bunga</h4>
# <p>Rata-rata rasio uang muka relatif rendah (sekitar 7.96%), namun ada beberapa outlier yang memiliki rasio uang muka sangat tinggi (hingga 100%). Suku bunga utama yang rendah menunjukkan bahwa sebagian besar peminjam mendapatkan suku bunga yang terjangkau, tetapi terdapat variasi yang signifikan di antara beberapa aplikasi.</p>

# %%
# 3. Scatter Plot: Harga Barang (AMT_GOODS_PRICE) vs Jumlah Kredit (AMT_CREDIT)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AMT_GOODS_PRICE', y='AMT_CREDIT', data=data, alpha=0.3)
plt.title('Scatter Plot: Harga Barang vs Jumlah Kredit', fontsize=14)
plt.xlabel('Harga Barang (AMT_GOODS_PRICE)')
plt.ylabel('Jumlah Kredit (AMT_CREDIT)')
plt.show()

# %% [markdown]
# <h4>3. Korelasi yang Kuat Antara Harga Barang dan Jumlah Kredit</h4>
# <p>Ada korelasi sangat kuat antara harga barang yang dibiayai dan jumlah kredit yang diberikan. Hal ini menunjukkan bahwa peminjam sering kali mengambil kredit yang sesuai dengan nilai barang yang ingin mereka beli, terutama untuk barang-barang dengan harga tinggi.</p>

# %% [markdown]
# <h3>Business Recommendation</h3>
#
# <h4>1. Diversifikasi Produk Pinjaman</h4>
# <p><strong>Insight:</strong> Sebagian besar aplikasi pinjaman adalah <i>cash loans</i>, dengan kategori pinjaman lainnya relatif jarang digunakan.</p>
# <p><strong>Rekomendasi:</strong> Bank atau lembaga keuangan dapat menawarkan produk pinjaman yang lebih beragam dan disesuaikan untuk berbagai kebutuhan konsumen, seperti pinjaman khusus untuk kendaraan, pendidikan, atau perbaikan rumah. Ini bisa membantu menarik pelanggan baru yang membutuhkan solusi pembiayaan yang lebih spesifik.</p>
#
# <h4>2. Optimalkan Proses Persetujuan yang Cepat</h4>
# <p><strong>Insight:</strong> Waktu keputusan dan penarikan dana cenderung cepat setelah aplikasi diproses, meskipun beberapa keputusan diambil jauh sebelum waktu aplikasi.</p>
# <p><strong>Rekomendasi:</strong> Perusahaan bisa mengimplementasikan teknologi otomatisasi dalam proses persetujuan pinjaman untuk mempersingkat waktu persetujuan lebih lanjut, memastikan penarikan pinjaman dilakukan dengan lebih cepat, dan meningkatkan pengalaman pelanggan.</p>
#
# <h4>3. Penanganan Outlier dan Data Anomali</h4>
# <p><strong>Insight:</strong> Beberapa kolom menunjukkan nilai anomali atau outlier, seperti nilai negatif pada <code>AMT_DOWN_PAYMENT</code> dan <code>RATE_DOWN_PAYMENT</code>.</p>
# <p><strong>Rekomendasi:</strong> Perlu dilakukan pembersihan dan validasi data secara berkala. Data yang tidak valid, seperti nilai negatif yang tidak logis, harus dihapus atau diperbaiki untuk meningkatkan kualitas analisis.</p>
#
# <h4>4. Tingkatkan Dokumentasi Tujuan Pinjaman</h4>
# <p><strong>Insight:</strong> Sebagian besar tujuan pinjaman tidak dijelaskan dengan jelas dalam dataset.</p>
# <p><strong>Rekomendasi:</strong> Bank sebaiknya meminta peminjam untuk memberikan lebih banyak informasi terkait tujuan pinjaman. Ini bisa membantu lembaga keuangan dalam memberikan produk yang lebih relevan, serta memungkinkan analisis yang lebih baik dalam penilaian risiko.</p>
#
# <h4>5. Pengembangan Layanan untuk Klien yang Mengajukan Ulang Pinjaman</h4>
# <p><strong>Insight:</strong> Sebagian besar klien adalah <i>repeater</i> yang telah mengajukan pinjaman sebelumnya.</p>
# <p><strong>Rekomendasi:</strong> Perusahaan dapat mengembangkan layanan khusus yang menawarkan program loyalitas atau insentif bagi pelanggan yang sering mengajukan pinjaman, misalnya dengan penawaran suku bunga yang lebih rendah atau persetujuan yang lebih cepat untuk pemohon yang memenuhi kriteria tertentu.</p>
#
# <h4>6. Pengelolaan Risiko yang Lebih Baik Melalui Asuransi Pinjaman</h4>
# <p><strong>Insight:</strong> Mayoritas pinjaman tidak diasuransikan saat persetujuan.</p>
# <p><strong>Rekomendasi:</strong> Bank dapat menawarkan produk asuransi pinjaman yang lebih menarik dan terjangkau untuk melindungi peminjam dan lembaga keuangan dari risiko gagal bayar. Ini bisa menjadi bagian dari paket pinjaman yang disarankan kepada klien untuk mengurangi risiko kredit macet.</p>
#
# <h4>7. Peningkatan Kualitas Data</h4>
# <p><strong>Insight:</strong> Banyak kategori yang memiliki nilai "XNA," yang mengindikasikan data yang tidak lengkap atau tidak didefinisikan dengan baik.</p>
# <p><strong>Rekomendasi:</strong> Lakukan audit data secara berkala untuk memastikan bahwa semua data yang dimasukkan sudah lengkap dan akurat. Perusahaan juga dapat mengembangkan sistem validasi otomatis untuk mengurangi entri data yang tidak valid.</p>
#
# <h3>Kesimpulan</h3>
# <p>Secara keseluruhan, analisis data ini menunjukkan adanya peluang bagi lembaga keuangan untuk meningkatkan layanan mereka, baik melalui diversifikasi produk pinjaman, optimalisasi proses persetujuan, maupun penanganan data yang lebih baik. Pengembangan layanan berbasis data dan peningkatan pengalaman pelanggan dapat membantu bank dalam memperluas pasar, meningkatkan profitabilitas, dan mengelola risiko dengan lebih efektif.</p>
